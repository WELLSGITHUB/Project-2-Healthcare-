# %% [markdown]
# ### Import libraries and create data frame

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Prepare Data

# %%
stroke_df = pd.read_csv("Resources/healthcare-dataset-stroke-data.csv")
stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
'''
# Standardize Data Formats
# Convert categorical columns to 'category' type
stroke_df['gender'] = stroke_df['gender'].str.lower().astype('category')
stroke_df['ever_married'] = stroke_df['ever_married'].str.lower().astype('category')
stroke_df['work_type'] = stroke_df['work_type'].str.lower().astype('category')
stroke_df['Residence_type'] = stroke_df['Residence_type'].str.lower().astype('category')
stroke_df['smoking_status'] = stroke_df['smoking_status'].str.lower().astype('category')
'''
# Out:
# "\n# Standardize Data Formats\n# Convert categorical columns to 'category' type\nstroke_df['gender'] = stroke_df['gender'].str.lower().astype('category')\nstroke_df['ever_married'] = stroke_df['ever_married'].str.lower().astype('category')\nstroke_df['work_type'] = stroke_df['work_type'].str.lower().astype('category')\nstroke_df['Residence_type'] = stroke_df['Residence_type'].str.lower().astype('category')\nstroke_df['smoking_status'] = stroke_df['smoking_status'].str.lower().astype('category')\n"

# %%
# Ensure Consistency
# Convert 'id' to string 
stroke_df['id'] = stroke_df['id'].astype(str)

# %%
# Display the cleaned DataFrame and its data types
display(stroke_df.head())
print(stroke_df.dtypes)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# id                    object
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
stroke_df['smoking_status'].value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %% [markdown]
# ### Split into X and y

# %%
X = stroke_df.drop(columns=['id', 'stroke'])
X.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status
# 0          Urban             228.69  36.6  formerly smoked
# 1          Rural             202.21   NaN     never smoked
# 2          Rural             105.92  32.5     never smoked
# 3          Urban             171.23  34.4           smokes
# 4          Rural             174.12  24.0     never smoked

# %%
y = stroke_df['stroke']

# %% [markdown]
# ### Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
X_train.isna().sum()/len(stroke_df)
# Out:
# gender               0.000000
# age                  0.000000
# hypertension         0.000000
# heart_disease        0.000000
# ever_married         0.000000
# work_type            0.000000
# Residence_type       0.000000
# avg_glucose_level    0.000000
# bmi                  0.029941
# smoking_status       0.000000
# dtype: float64

# %%
(X_train['smoking_status'] == 'Unknown').sum()/len(stroke_df)
# Out:
# 0.22857142857142856

# %%
# Handle Missing Values
# Fill missing values in the 'bmi' column with the mean
X_train['bmi'] = X_train['bmi'].fillna(stroke_df['bmi'].mean())

# %%
X_train.isna().sum()/len(stroke_df)
# Out:
# gender               0.0
# age                  0.0
# hypertension         0.0
# heart_disease        0.0
# ever_married         0.0
# work_type            0.0
# Residence_type       0.0
# avg_glucose_level    0.0
# bmi                  0.0
# smoking_status       0.0
# dtype: float64

# %%
X_train.loc[X_train['smoking_status'] == 'Unknown'].describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  1168.000000   1168.000000    1168.000000        1168.000000
# mean     30.671267      0.035103       0.031678          98.730385
# std      25.336018      0.184118       0.175217          36.309063
# min       0.080000      0.000000       0.000000          55.280000
# 25%       8.000000      0.000000       0.000000          76.465000
# 50%      23.000000      0.000000       0.000000          89.260000
# 75%      52.000000      0.000000       0.000000         109.047500
# max      82.000000      1.000000       1.000000         260.850000
#
#                bmi
# count  1168.000000
# mean     25.742011
# std       7.833756
# min      10.300000
# 25%      19.600000
# 50%      24.900000
# 75%      29.800000
# max      97.600000

# %%
X_train.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  3832.000000   3832.000000    3832.000000        3832.000000
# mean     43.280021      0.098121       0.054541         105.521550
# std      22.585163      0.297517       0.227111          45.224729
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          76.607500
# 50%      45.000000      0.000000       0.000000          91.185000
# 75%      61.000000      0.000000       0.000000         113.495000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi
# count  3832.000000
# mean     28.961108
# std       7.651613
# min      10.300000
# 25%      23.900000
# 50%      28.450000
# 75%      32.825000
# max      97.600000

# %%
X_train['age'].plot(kind='hist',alpha=0.2)
X_train.loc[stroke_df['smoking_status'] == 'Unknown', 'age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# We will assume most of the unknown values below the legal smoking age fall into the never smoked category
for index, row in X_train.iterrows():
    if row['age'] <= 18:
        X_train.at[index, 'smoking_status'] = 'never smoked'

(X_train['smoking_status'] == 'Unknown').sum()/len(stroke_df)
# Out:
# 0.1232876712328767

# %%
'''
for x in stroke_df:
    display(stroke_df[x].value_counts())
'''
# Out:
# '\nfor x in stroke_df:\n    display(stroke_df[x].value_counts())\n'

# %% [markdown]
# ## Encode the dataset

# %%
#encode# List 
categorical_columns = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

#One-Hot Encoding with pd.get_dummies
X_train_encoded = pd.get_dummies(X_train, columns=categorical_columns, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, columns=categorical_columns, drop_first=True)

#Check the data
X_train_encoded.head()
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  gender_Male  \
# 1914  43.0             0              0              77.86  28.9         True
# 1751  65.0             0              0              88.82  28.2        False
# 396   60.0             1              0             213.37  36.0         True
# 1783   2.0             0              0              65.67  16.6         True
# 2361  30.0             0              0             101.98  23.2        False
#
#       ever_married_Yes  work_type_Never_worked  work_type_Private  \
# 1914              True                   False               True
# 1751              True                   False               True
# 396               True                   False               True
# 1783             False                   False              False
# 2361              True                   False               True
#
#       work_type_Self-employed  work_type_children  Residence_type_Urban  \
# 1914                    False               False                 False
# 1751                    False               False                  True
# 396                     False               False                 False
# 1783                    False                True                 False
# 2361                    False               False                  True
#
#       smoking_status_formerly smoked  smoking_status_never smoked  \
# 1914                           False                         True
# 1751                            True                        False
# 396                            False                         True
# 1783                           False                         True
# 2361                           False                        False
#
#       smoking_status_smokes
# 1914                  False
# 1751                  False
# 396                   False
# 1783                  False
# 2361                  False

# %%
X_test_encoded.head()
X_test_encoded['gender_Other'].value_counts()
X_test_encoded = X_test_encoded.drop(columns= 'gender_Other', axis=1)

# %% [markdown]
# ## Random Oversampling

# %%
# Import RandomOverSampler from imblearn
from imblearn.over_sampling import RandomOverSampler

# Instantiate the RandomOverSampler instance
random_oversampler = RandomOverSampler(random_state=1)

# Fit the data to the model
X_resampled, y_resampled = random_oversampler.fit_resample(X_train_encoded, y_train)

# %%
# Count distinct resampled values
y_resampled.value_counts()
# Out:
# stroke
# 0    3658
# 1    3658
# Name: count, dtype: int64

# %%
# 
X_train_encoded
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  gender_Male  \
# 1914  43.0             0              0              77.86  28.9         True
# 1751  65.0             0              0              88.82  28.2        False
# 396   60.0             1              0             213.37  36.0         True
# 1783   2.0             0              0              65.67  16.6         True
# 2361  30.0             0              0             101.98  23.2        False
# ...    ...           ...            ...                ...   ...          ...
# 2895  46.0             0              0             137.77  29.3         True
# 2763  45.0             0              0              63.73  32.0        False
# 905   31.0             0              0              76.26  35.6        False
# 3980  45.0             0              0             218.10  55.0        False
# 235   68.0             0              0             211.06  39.3        False
#
#       ever_married_Yes  work_type_Never_worked  work_type_Private  \
# 1914              True                   False               True
# 1751              True                   False               True
# 396               True                   False               True
# 1783             False                   False              False
# 2361              True                   False               True
# ...                ...                     ...                ...
# 2895              True                   False               True
# 2763              True                   False               True
# 905               True                   False               True
# 3980              True                   False               True
# 235               True                   False               True
#
#       work_type_Self-employed  work_type_children  Residence_type_Urban  \
# 1914                    False               False                 False
# 1751                    False               False                  True
# 396                     False               False                 False
# 1783                    False                True                 False
# 2361                    False               False                  True
# ...                       ...                 ...                   ...
# 2895                    False               False                  True
# 2763                    False               False                 False
# 905                     False               False                 False
# 3980                    False               False                 False
# 235                     False               False                 False
#
#       smoking_status_formerly smoked  smoking_status_never smoked  \
# 1914                           False                         True
# 1751                            True                        False
# 396                            False                         True
# 1783                           False                         True
# 2361                           False                        False
# ...                              ...                          ...
# 2895                           False                         True
# 2763                           False                        False
# 905                            False                         True
# 3980                           False                        False
# 235                            False                        False
#
#       smoking_status_smokes
# 1914                  False
# 1751                  False
# 396                   False
# 1783                  False
# 2361                  False
# ...                     ...
# 2895                  False
# 2763                  False
# 905                   False
# 3980                   True
# 235                   False
#
# [3832 rows x 15 columns]

# %%
# Instantiate an initial RamdonForestClassifier instance
model = RandomForestClassifier()

# Fit the initial model based the training data
model.fit(X_resampled, y_resampled)
# Out:
# RandomForestClassifier()

# %%
# Make predictions for testing features
y_pred = model.predict(X_test_encoded)

# %%
# Print the classification reports for the two models
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      1203
#            1       0.11      0.03      0.04        75
#
#     accuracy                           0.93      1278
#    macro avg       0.53      0.51      0.50      1278
# weighted avg       0.89      0.93      0.91      1278
